# %%
import requests
import pandas as pd

# %%
# URL DE LA API DEL BCRA

api_url = "https://api.bcra.gob.ar/estadisticas/v2.0/principalesvariables"

# %%
# Función para hacer la petición a la API
def obtener_datos_bcra():
  url = f"{api_url}"
  response = requests.get(url, verify=False) # Desactiva la verificación SSL
  return response.json()

# %%
df = pd.DataFrame(obtener_datos_bcra()["results"])
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    idVariable  cdSerie                                        descripcion  \
# 0           1      246  Reservas Internacionales del BCRA (en millones...
# 1           4     7927  Tipo de Cambio Minorista ($ por USD) Comunicac...
# 2           5      272  Tipo de Cambio Mayorista ($ por USD) Comunicac...
# 3           6     7935             Tasa de Política Monetaria (en % n.a.)
# 4           7     1222     BADLAR en pesos de bancos privados (en % n.a.)
#
#         fecha       valor
# 0  2025-01-22  30140.0000
# 1  2025-01-24   1075.7800
# 2  2025-01-24   1049.5800
# 3  2025-01-24     32.0000
# 4  2025-01-23     31.3125

# %%
df = pd.DataFrame(obtener_datos_bcra()["results"])

# Eliminar las columnas 'cdSerie', 'fecha' e 'idVariable'
df_cleaned = df.drop(columns=['cdSerie', 'fecha', 'idVariable'])

# Formatear la columna 'valor' a dos decimales y separadores de miles
df_cleaned['valor'] = df_cleaned['valor'].apply(lambda x: f"{x:,.2f}")

print(df_cleaned)
# Out:
#                                           descripcion           valor
# 0   Reservas Internacionales del BCRA (en millones...       30,140.00
# 1   Tipo de Cambio Minorista ($ por USD) Comunicac...        1,075.78
# 2   Tipo de Cambio Mayorista ($ por USD) Comunicac...        1,049.58
# 3              Tasa de Política Monetaria (en % n.a.)           32.00
# 4      BADLAR en pesos de bancos privados (en % n.a.)           31.31
# 5        TM20 en pesos de bancos privados (en % n.a.)           32.25
# 6   Tasas de interés de las operaciones de pase ac...           36.00
# 7   Tasas de interés de las operaciones de pase pa...           40.00
# 8   Tasas de interés por préstamos entre entidades...           35.23
# 9   Tasas de interés por depósitos a 30 días de pl...           29.98
# 10  Tasa de interés de préstamos por adelantos en ...           39.10
# 11            Tasa de interés de préstamos personales           70.96
# 12      Base monetaria - Total (en millones de pesos)   30,090,521.00
# 13       Circulación monetaria (en millones de pesos)   19,865,761.00
# 14  Billetes y monedas en poder del público (en mi...   17,906,584.00
# 15  Efectivo en entidades financieras (en millones...    1,959,177.00
# 16  Depósitos de los bancos en cta. cte. en pesos ...   10,224,760.00
# 17  Depósitos en efectivo en las entidades financi...  139,691,204.00
# 18  En cuentas corrientes (neto de utilización FUC...   24,328,678.00
# 19          En Caja de ahorros (en millones de pesos)   51,461,304.00
# 20  A plazo (incluye inversiones y excluye CEDROS)...   56,926,357.00
# 21  M2 privado, promedio móvil de 30 días, variaci...           60.50
# 22  Préstamos de las entidades financieras al sect...   68,136,377.00
# 23                 Inflación mensual (variación en %)            2.70
# 24         Inflación interanual (variación en % i.a.)          117.80
# 25  Inflación esperada - REM próximos 12 meses - M...           25.90
# 26                              CER (Base 2.2.2002=1)          525.52
# 27  Unidad de Valor Adquisitivo (UVA) (en pesos -c...        1,325.96
# 28  Unidad de Vivienda (UVI) (en pesos -con dos de...          980.92
# 29             Tasa de Política Monetaria (en % e.a.)           37.69
# 30     BADLAR en pesos de bancos privados (en % e.a.)           36.19
# 31  Índice para Contratos de Locación (ICL-Ley 27....           22.17
# 32  Tasas de interés de las operaciones de pase pa...           49.15
# 33  Pases pasivos para el BCRA - Saldos (en millon...            0.00
# 34  Tasa de interés para uso de la Justicia – Comu...       18,207.89
# 35      TAMAR en pesos de bancos privados (en % n.a.)           33.31
# 36      TAMAR en pesos de bancos privados (en % e.a.)           38.87
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
